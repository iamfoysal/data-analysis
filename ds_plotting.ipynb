# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

health_data = pd.read_csv("files/workout_data.csv", header=0, sep=",")
health_data.plot(x ='Average_Pulse', y='Calorie_Burnage', kind='line')
plt.ylim(ymin=0)
plt.xlim(xmin=0)

plt.show()
